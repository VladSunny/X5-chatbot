# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("chatbot.db")

# %%
pd.read_sql("SELECT * FROM feedback", conn)
# Out:
#    id                            message_id feedback           api_key
# 0   1  9eca9957-6573-4571-b70c-927659fefdfa     like  test-api-key-123
# 1   2  3c616372-351a-4ee4-b1d9-a9a6a29f996c  dislike  test-api-key-123
# 2   3  40230295-b638-42ef-a51d-f0ab22d12729     like  test-api-key-123
# 3   4  54d09ac2-a156-4e93-a161-acced5d8f9e7     like  test-api-key-123

# %%
pd.read_sql("SELECT * FROM messages", conn)
# Out:
#    id           api_key       role  \
# 0   1  test-api-key-123       user
# 1   2  test-api-key-123  assistant
# 2   3  test-api-key-123       user
# 3   4  test-api-key-123  assistant
# 4   5  test-api-key-123       user
# 5   6  test-api-key-123  assistant
# 6   7  test-api-key-123       user
# 7   8  test-api-key-123  assistant
#
#                                                 text  \
# 0                                     апорапорпаорпа
# 1  Получено: апорапорпаорпа. Это заглушка ответа ...
# 2                                                  а
# 3            Получено: а. Это заглушка ответа от AI!
# 4                                                  а
# 5            Получено: а. Это заглушка ответа от AI!
# 6                                                 ва
# 7           Получено: ва. Это заглушка ответа от AI!
#
#                              message_id
# 0  b5a05658-c1d2-4210-aa7d-e92eca434fa2
# 1  9eca9957-6573-4571-b70c-927659fefdfa
# ...
