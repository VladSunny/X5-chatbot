# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("chatbot.db")

# %%
pd.read_sql("SELECT * FROM feedback", conn)
# Out:
#    id                            message_id feedback           api_key
# 0   3  ebaf8ff9-e86f-44b4-9add-48e62e6aff51  dislike  test-api-key-123
# 1   4  e4a6e242-29b2-4160-bbb3-cd2c9c0ce3dc     like  test-api-key-123
# 2   5  d537abe2-8fff-44f9-a604-b17221a3051d     like  test-api-key-123

# %%
pd.read_sql("SELECT * FROM messages", conn)
# Out:
#    id           api_key       role  \
# 0  13  test-api-key-123       user
# 1  14  test-api-key-123  assistant
# 2  15  test-api-key-123       user
# 3  16  test-api-key-123  assistant
# 4  17  test-api-key-123       user
# 5  18  test-api-key-123  assistant
#
#                                            text  \
# 0                                        ававва
# 1  Получено: ававва. Это заглушка ответа от AI!
# 2                                            ав
# 3      Получено: ав. Это заглушка ответа от AI!
# 4                                            ав
# 5      Получено: ав. Это заглушка ответа от AI!
#
#                              message_id
# 0  47bf730f-c0f5-4a2b-9f81-cba338c2365d
# 1  ebaf8ff9-e86f-44b4-9add-48e62e6aff51
# 2  9fea6b63-b2b5-4ad7-b653-79624c950f67
# 3  e4a6e242-29b2-4160-bbb3-cd2c9c0ce3dc
# 4  38c3429c-f2f4-444d-806e-dd2150f129be
# 5  d537abe2-8fff-44f9-a604-b17221a3051d
