# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("chatbot.db")

# %%
df = pd.read_sql("SELECT * FROM feedback", conn)

# %%
df
# Out:
#    id                            message_id feedback           api_key
# 0   1  5e1d49e9-94dc-427b-a466-b8dc4457e4c9     like  test-api-key-123
# 1   2  ff7302ae-3a69-4088-b6d6-7cefd962264b  dislike  test-api-key-123
# 2   3  47ee03c4-5d21-4b9e-8e34-3950bae34941     like  test-api-key-123
# 3   4  358b0d0b-ab9f-41f1-b1dd-f01b56bda1f6  dislike  test-api-key-123
# 4   5  358b0d0b-ab9f-41f1-b1dd-f01b56bda1f6     like  test-api-key-123
