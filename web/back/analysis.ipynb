# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("chatbot.db")

# %%
pd.read_sql("SELECT * FROM feedback", conn)
# Out:
#    id                            message_id feedback           api_key
# 0   1  c31df641-dbd5-45d7-a7e3-5afe96409604     like  test-api-key-456
# 1   2  c8577a0d-208e-4f53-ace9-565be177ba82     like  test-api-key-456
# 2   3  dcb4e2de-5cc9-42c0-b7c4-05f6b42002bf     like  test-api-key-456
# 3   4  d6fb2199-6596-4286-9716-d8ab93e7fafd     like  test-api-key-456
# 4   5  d8b045ea-01bf-42f7-a4d4-c860d3345e3b     like  test-api-key-456
# 5   6  c6dc12bb-66fb-4c17-b6af-2a727c69abba     like  test-api-key-456
# 6   7  d72868b9-0f95-49d5-9ad0-2f5046cc1e40     like  test-api-key-456

# %%
pd.read_sql("SELECT * FROM messages", conn)
# Out:
#     id           api_key       role  \
# 0    1  test-api-key-456  assistant
# 1    2  test-api-key-456       user
# 2    3  test-api-key-456  assistant
# 3    4  test-api-key-456       user
# 4    5  test-api-key-456  assistant
# 5    6  test-api-key-456       user
# 6    7  test-api-key-456  assistant
# 7    8  test-api-key-456       user
# 8    9  test-api-key-456  assistant
# 9   10  test-api-key-456       user
# 10  11  test-api-key-456  assistant
# 11  12  test-api-key-456       user
# 12  13  test-api-key-456  assistant
# 13  14  test-api-key-456       user
#
#                                                  text  \
# 0   Для внесения данных по личному автомобилю обра...
# 1                           как зарегестрирова машину
# 2   Заработная плата в нашей компании выплачиваетс...
# 3                                     когда зарплата?
# 4   Не уверен, что понял вас, попробуйте добавить ...
# 5                                                пиво
# 6   Не уверен, что понял вас, попробуйте добавить ...
# 7                                    опаплодаволавлоа
# 8   Не уверен, что понял вас, попробуйте добавить ...
# 9                                           пися попа
# 10  Создать заявку на отпуск можно в разделе "Серв...
# 11                                как оформить отпуск
# 12  Обратитесь к HRBP для создания заявки "Админис...
# 13                               я хочу уйти в декрет
#
#                               message_id
# 0   c31df641-dbd5-45d7-a7e3-5afe96409604
# 1   ba0d4ee2-6323-40c1-9109-fc9987240ed4
# 2   c8577a0d-208e-4f53-ace9-565be177ba82
# 3   31d02cbc-ea11-485d-9676-b7373340623e
# 4   dcb4e2de-5cc9-42c0-b7c4-05f6b42002bf
# 5   8327b7dc-f3c1-4521-aae2-955004ff8953
# 6   d6fb2199-6596-4286-9716-d8ab93e7fafd
# 7   fb2c3e19-ff05-4e72-9e32-d40ec7177a70
# 8   d8b045ea-01bf-42f7-a4d4-c860d3345e3b
# 9   a82f8a7d-5ee4-4588-a6bc-3d0042a66f1d
# 10  c6dc12bb-66fb-4c17-b6af-2a727c69abba
# 11  14917853-4501-4e8e-bc01-25e2b383957e
# 12  d72868b9-0f95-49d5-9ad0-2f5046cc1e40
# 13  494176c3-9ee3-4b7a-b9cc-4a3d585d9eca
